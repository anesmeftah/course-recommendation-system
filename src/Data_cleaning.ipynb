# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
courses = pd.read_csv('../Data/Coursera.csv')
courses.head(2)
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
#
#                                   Course Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
#
#                                               Skills
# 0  Drama  Comedy  peering  screenwriting  film  D...
# 1  Finance  business plan  persona (user experien...

# %%
courses.columns , courses.shape
# Out:
# (Index(['Course Name', 'University', 'Difficulty Level', 'Course Rating',
#         'Course URL', 'Course Description', 'Skills'],
#        dtype='object'),
#  (3522, 7))

# %%
courses.isna().sum()
# Out:
# Course Name           0
# University            0
# Difficulty Level      0
# Course Rating         0
# Course URL            0
# Course Description    0
# Skills                0
# dtype: int64

# %%
courses.describe()
# Out:
#                                               Course Name  \
# count                                                3522
# unique                                               3416
# top     Google Cloud Platform Fundamentals: Core Infra...
# freq                                                    8
#
#                       University Difficulty Level Course Rating  \
# count                       3522             3522          3522
# unique                       184                5            31
# top     Coursera Project Network         Beginner           4.7
# freq                         562             1444           740
#
#                                              Course URL  \
# count                                              3522
# unique                                             3424
# top     https://www.coursera.org/learn/gcp-fundamentals
# freq                                                  8
#
#                                        Course Description  \
# ...

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Course Name         3522 non-null   object
#  1   University          3522 non-null   object
#  2   Difficulty Level    3522 non-null   object
#  3   Course Rating       3522 non-null   object
#  4   Course URL          3522 non-null   object
#  5   Course Description  3522 non-null   object
#  6   Skills              3522 non-null   object
# dtypes: object(7)
# memory usage: 192.7+ KB

# %%
# Check for duplicated Course Names
duplicated_courses = courses[courses.duplicated('Course Name', keep=False)]
duplicated_courses[['Course Name']]
# Out:
#                                             Course Name
# 43    Introduction to Cybersecurity Tools & Cyber At...
# 44    Introduction to Cybersecurity Tools & Cyber At...
# 94                                       Guided Imagery
# 96    Building Resilient Streaming Analytics Systems...
# 158                                      Guided Imagery
# ...                                                 ...
# 3491                      Applied Data Science Capstone
# 3499  Google Cloud Platform Fundamentals: Core Infra...
# 3500  Google Cloud Platform Fundamentals: Core Infra...
# 3503                Copyright Law in the Music Business
# 3504                Copyright Law in the Music Business
#
# [188 rows x 1 columns]

# %%
duplicated_courses.head(5) #Check if there any difference
# Out:
#                                            Course Name  \
# 43   Introduction to Cybersecurity Tools & Cyber At...
# 44   Introduction to Cybersecurity Tools & Cyber At...
# 94                                      Guided Imagery
# 96   Building Resilient Streaming Analytics Systems...
# 158                                     Guided Imagery
#
#                   University Difficulty Level Course Rating  \
# 43                       IBM         Beginner           4.3
# 44                       IBM         Beginner           4.3
# 94   University of Minnesota     Intermediate           4.8
# 96              Google Cloud         Advanced           4.6
# 158  University of Minnesota     Intermediate           4.8
#
#                                             Course URL  \
# 43   https://www.coursera.org/learn/introduction-cy...
# 44   https://www.coursera.org/learn/introduction-cy...
# 94       https://www.coursera.org/learn/guided-imagery
# ...

# %%
#delete duplicated courses
courses = courses.drop_duplicates('Course Name', keep='first')

# %%
courses.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# ...

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3416 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Course Name         3416 non-null   object
#  1   University          3416 non-null   object
#  2   Difficulty Level    3416 non-null   object
#  3   Course Rating       3416 non-null   object
#  4   Course URL          3416 non-null   object
#  5   Course Description  3416 non-null   object
#  6   Skills              3416 non-null   object
# dtypes: object(7)
# memory usage: 213.5+ KB

# %%
courses.insert(0 , 'ID' , range(0,3416))
courses.head()
# Out:
#    ID                                        Course Name  \
# 0   0  Write A Feature Length Screenplay For Film Or ...
# 1   1  Business Strategy: Business Model Canvas Analy...
# 2   2                      Silicon Thin Film Solar Cells
# 3   3                               Finance for Managers
# 4   4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# ...

# %%
mapping = {'Beginner' : 0 ,
           'Intermediate' : 1,
           'Advanced' : 2}

courses["Difficulty Level"] = courses["Difficulty Level"].map(mapping)

courses.head()
# Out:
#    ID                                        Course Name  \
# 0   0  write a feature length screenplay for film or ...
# 1   1  business strategy: business model canvas analy...
# 2   2                      silicon thin film solar cells
# 3   3                               finance for managers
# 4   4       retrieve data using single-table sql queries
#
#                   University  Difficulty Level Course Rating  \
# 0  michigan state university               0.0           4.8
# 1   coursera project network               0.0           4.8
# 2        �cole polytechnique               2.0           4.1
# 3       iese business school               1.0           4.8
# 4   coursera project network               0.0           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# ...

# %%
courses['Course Name'] = courses['Course Name'].str.lower()
courses['University'] = courses['University'].str.lower()
courses['Course Description'] = courses['Course Description'].str.lower()
courses['Skills'] = courses['Skills'].str.lower()

# %%
courses.head()
# Out:
#    ID                                        Course Name  \
# 0   0  write a feature length screenplay for film or ...
# 1   1  business strategy: business model canvas analy...
# 2   2                      silicon thin film solar cells
# 3   3                               finance for managers
# 4   4       retrieve data using single-table sql queries
#
#                   University Difficulty Level Course Rating  \
# 0  michigan state university         Beginner           4.8
# 1   coursera project network         Beginner           4.8
# 2        �cole polytechnique         Advanced           4.1
# 3       iese business school     Intermediate           4.8
# 4   coursera project network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# ...

# %%
courses.to_csv("../Data/cleaned_courses.csv")

# %%
len(courses['University'].unique())
# Out:
# 184

# %%
sns.countplot(y='University', data=courses, order=courses['University'].value_counts().index[:10])
plt.title('Top 10 Universities')
plt.show()

# %%
sns.countplot(x='Difficulty Level', data=courses)
plt.title('Course Difficulty Levels')
plt.show()
